# %%
import numpy as np
import matplotlib.pyplot as plt
import cPickle as p
import glob
import os

# %%
ls
# Out:
# 1.txt                            TwoPoint_PlotMaker.ipynb
# Plots/                           TwoPoint_PlotMakerLoop.ipynb
# README.md                        TwoPoint_Tutorial.ipynb
# Two-Point.png                    Untitled.ipynb
# TwoPoint_Calculator.ipynb        data/
# TwoPoint_Function.ipynb          index.html
# TwoPoint_Loop.ipynb              metal_correlation-example.ipynb

# %%
ls ./data
# Out:
# R8_8pc_metal.0000.scal0.p      R8_8pc_metal.0350.scal0.p.txt
# R8_8pc_metal.0000.scal0.p.txt  R8_8pc_metal.0351.scal0.p
# R8_8pc_metal.0001.scal0.p      R8_8pc_metal.0351.scal0.p.txt
# R8_8pc_metal.0001.scal0.p.txt  R8_8pc_metal.0352.scal0.p
# R8_8pc_metal.0002.scal0.p      R8_8pc_metal.0352.scal0.p.txt
# R8_8pc_metal.0002.scal0.p.txt  R8_8pc_metal.0353.scal0.p
# R8_8pc_metal.0003.scal0.p      R8_8pc_metal.0353.scal0.p.txt
# R8_8pc_metal.0003.scal0.p.txt  R8_8pc_metal.0354.scal0.p
# R8_8pc_metal.0004.scal0.p      R8_8pc_metal.0354.scal0.p.txt
# R8_8pc_metal.0004.scal0.p.txt  R8_8pc_metal.0355.scal0.p
# R8_8pc_metal.0005.scal0.p      R8_8pc_metal.0355.scal0.p.txt
# R8_8pc_metal.0005.scal0.p.txt  R8_8pc_metal.0356.scal0.p
# R8_8pc_metal.0006.scal0.p      R8_8pc_metal.0356.scal0.p.txt
# R8_8pc_metal.0006.scal0.p.txt  R8_8pc_metal.0357.scal0.p
# R8_8pc_metal.0007.scal0.p      R8_8pc_metal.0357.scal0.p.txt
# R8_8pc_metal.0007.scal0.p.txt  R8_8pc_metal.0358.scal0.p
# ...

# %%
textList = List = glob.glob(os.path.join('./data/', '*.txt'))
print len(textList)
# Out:
# 701
